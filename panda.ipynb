# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/PREET/OneDrive/Desktop/Tamil_nadu_taxi_trips_.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1491 entries, 0 to 1490
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date_Time             1491 non-null   object
#  1   Pickup_Location       1491 non-null   object
#  2   Drop_Location         1491 non-null   object
#  3   Distance_km           1444 non-null   float64
#  4   Fare_INR              1427 non-null   float64
#  5   No_of_Passengers      1457 non-null   float64
#  6   Travel_Time_hrs       1473 non-null   float64
#  7   Tips_INR              1471 non-null   float64
#  8   Tourist_Place_Nearby  1491 non-null   object
#  9   Weather_Condition     1472 non-null   object
#  10  Vehicle_Type          1485 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 128.3+ KB

# %%
df.head(1300)
# Out:
#              Date_Time Pickup_Location Drop_Location  Distance_km  Fare_INR  \
# 0     25-10-2011 22:58        Namakkal   Krishnagiri         65.8   1076.40
# 1     03-01-2014 10:11  Ramanathapuram  Nagapattinam          NaN   1298.39
# 2     26-07-2011 10:06     Tirunelveli     Thanjavur        121.7   1869.84
# 3     25-08-2011 19:16           Karur      Namakkal        176.7   2828.04
# 4     07-08-2013 18:29        Namakkal         Theni        281.2   4100.53
# ...                ...             ...           ...          ...       ...
# 1295  15-04-2010 05:42       Cuddalore         Karur         54.7    828.20
# 1296  07-11-2012 01:45           Karur         Theni         46.3    652.48
# 1297  28-03-2015 23:48       Thanjavur    Coimbatore        194.7   3045.55
# 1298  10-09-2017 20:47           Erode   Krishnagiri        166.4   2336.61
# 1299  29-08-2013 20:35       Cuddalore      Tiruppur         36.5    488.49
#
#       No_of_Passengers  Travel_Time_hrs  Tips_INR  \
# ...

# %%
df.shape
# Out:
# (1491, 11)

# %%
df.columns
# Out:
# Index(['Date_Time', 'Pickup_Location', 'Drop_Location', 'Distance_km',
#        'Fare_INR', 'No_of_Passengers', 'Travel_Time_hrs', 'Tips_INR',
#        'Tourist_Place_Nearby', 'Weather_Condition', 'Vehicle_Type'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1491, step=1)

# %%
df.tail()
# Out:
#              Date_Time Pickup_Location Drop_Location  Distance_km  Fare_INR  \
# 1486  11-04-2010 22:48    Nagapattinam     Thanjavur        205.3   3096.91
# 1487  30-09-2011 22:30        Namakkal       Chennai        136.6   2227.24
# 1488  18-10-2015 07:28      Dharmapuri         Karur        107.9   1515.77
# 1489  07-12-2015 18:39     Pudukkottai       Chennai         41.7    734.25
# 1490  09-08-2018 22:29       Sivaganga         Erode        221.8   3959.42
#
#       No_of_Passengers  Travel_Time_hrs  Tips_INR  \
# 1486               4.0             6.57    209.85
# 1487               3.0             2.04      0.00
# 1488               4.0             2.49      0.00
# 1489               3.0             0.90      0.00
# 1490               5.0             3.86      0.00
#
#                    Tourist_Place_Nearby Weather_Condition Vehicle_Type
# 1486               Brihadeeswara Temple             Sunny         Auto
# ...

# %%
df.describe()
# Out:
#        Distance_km     Fare_INR  No_of_Passengers  Travel_Time_hrs  \
# count  1444.000000  1427.000000       1457.000000      1473.000000
# mean    155.199169  2339.990960          3.481126         3.267101
# std      84.732445  1317.100111          1.726437         2.011627
# min      10.000000   136.850000          1.000000         0.170000
# 25%      82.225000  1202.535000          2.000000         1.660000
# 50%     156.150000  2326.590000          3.000000         3.080000
# 75%     228.575000  3417.350000          5.000000         4.580000
# max     299.700000  5301.510000          6.000000         9.540000
#
#           Tips_INR
# count  1471.000000
# mean     93.775765
# std     174.946411
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%     121.895000
# max     976.550000

# %%
df ['Drop_Location']
# Out:
# 0        Krishnagiri
# 1       Nagapattinam
# 2          Thanjavur
# 3           Namakkal
# 4              Theni
#             ...
# 1486       Thanjavur
# 1487         Chennai
# 1488           Karur
# 1489         Chennai
# 1490           Erode
# Name: Drop_Location, Length: 1491, dtype: object

# %%
df.loc[0]
# Out:
# Date_Time               25-10-2011 22:58
# Pickup_Location                 Namakkal
# Drop_Location                Krishnagiri
# Distance_km                         65.8
# Fare_INR                          1076.4
# No_of_Passengers                     6.0
# Travel_Time_hrs                     1.32
# Tips_INR                          113.49
# Tourist_Place_Nearby     Krishnagiri Dam
# Weather_Condition                  Windy
# Vehicle_Type                   Hatchback
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Date_Time                03-01-2014 10:11
# Pickup_Location            Ramanathapuram
# Drop_Location                Nagapattinam
# Distance_km                           NaN
# Fare_INR                          1298.39
# No_of_Passengers                      4.0
# Travel_Time_hrs                      2.85
# Tips_INR                           171.95
# Tourist_Place_Nearby    Velankanni Church
# Weather_Condition                   Rainy
# Vehicle_Type                          SUV
# Name: 1, dtype: object

# %%
df.loc[0:2]
# Out:
#           Date_Time Pickup_Location Drop_Location  Distance_km  Fare_INR  \
# 0  25-10-2011 22:58        Namakkal   Krishnagiri         65.8   1076.40
# 1  03-01-2014 10:11  Ramanathapuram  Nagapattinam          NaN   1298.39
# 2  26-07-2011 10:06     Tirunelveli     Thanjavur        121.7   1869.84
#
#    No_of_Passengers  Travel_Time_hrs  Tips_INR  Tourist_Place_Nearby  \
# 0               6.0             1.32    113.49       Krishnagiri Dam
# 1               4.0             2.85    171.95     Velankanni Church
# 2               1.0             2.21    168.59  Brihadeeswara Temple
#
#   Weather_Condition Vehicle_Type
# 0             Windy    Hatchback
# 1             Rainy          SUV
# 2             Rainy         Auto

# %%
df[df['Distance_km'] > 280]
# Out:
#              Date_Time Pickup_Location Drop_Location  Distance_km  Fare_INR  \
# 4     07-08-2013 18:29        Namakkal         Theni        281.2   4100.53
# 50    28-11-2013 15:01           Salem         Karur        299.7   5301.51
# 58    28-05-2016 15:05       Thanjavur         Erode        291.6   4872.34
# 62    06-01-2010 17:23     Tirunelveli       Vellore        299.0   5095.89
# 87    29-05-2013 00:11     Kanyakumari    Villupuram        289.5   4731.42
# ...                ...             ...           ...          ...       ...
# 1345  17-05-2016 21:07         Madurai  Nagapattinam        298.5   3587.24
# 1357  30-11-2016 19:22           Erode    Villupuram        281.7   4911.95
# 1376  22-12-2011 04:37    Nagapattinam         Erode        297.1   4656.56
# 1437  09-06-2010 05:55       Thanjavur       Madurai        297.2   4718.41
# 1465  18-02-2013 17:53     Pudukkottai   Tirunelveli        299.6   3827.04
#
#       No_of_Passengers  Travel_Time_hrs  Tips_INR  \
# ...

# %%
df[(df['Distance_km'] > 280) & (df['Pickup_Location'] == 'Thanjavur')]
# Out:
#              Date_Time Pickup_Location Drop_Location  Distance_km  Fare_INR  \
# 58    28-05-2016 15:05       Thanjavur         Erode        291.6   4872.34
# 936   26-03-2015 20:49       Thanjavur       Chennai        281.3   4212.87
# 1437  09-06-2010 05:55       Thanjavur       Madurai        297.2   4718.41
#
#       No_of_Passengers  Travel_Time_hrs  Tips_INR  \
# 58                 4.0             5.33    780.62
# 936                2.0             4.42      0.00
# 1437               4.0             7.07      0.00
#
#               Tourist_Place_Nearby Weather_Condition Vehicle_Type
# 58    Bhavani Sangameswarar Temple            Cloudy         Auto
# 936                   Marina Beach             Windy    Hatchback
# 1437              Meenakshi Temple             Windy     Mini Van

# %%
df.drop('Vehicle_Type', axis=1, inplace=True)

# %%
df.head()
# Out:
#           Date_Time Pickup_Location Drop_Location  Distance_km  Fare_INR  \
# 0  25-10-2011 22:58        Namakkal   Krishnagiri         65.8   1076.40
# 1  03-01-2014 10:11  Ramanathapuram  Nagapattinam          NaN   1298.39
# 2  26-07-2011 10:06     Tirunelveli     Thanjavur        121.7   1869.84
# 3  25-08-2011 19:16           Karur      Namakkal        176.7   2828.04
# 4  07-08-2013 18:29        Namakkal         Theni        281.2   4100.53
#
#    No_of_Passengers  Travel_Time_hrs  Tips_INR  Tourist_Place_Nearby  \
# 0               6.0             1.32    113.49       Krishnagiri Dam
# 1               4.0             2.85    171.95     Velankanni Church
# 2               1.0             2.21    168.59  Brihadeeswara Temple
# 3               3.0             2.81      0.00         Namakkal Fort
# 4               NaN             5.66    432.56          Suruli Falls
#
#   Weather_Condition
# 0             Windy
# 1             Rainy
# 2             Rainy
# 3             Rainy
# ...

# %%
df.isnull()
# Out:
#       Date_Time  Pickup_Location  Drop_Location  Distance_km  Fare_INR  \
# 0         False            False          False        False     False
# 1         False            False          False         True     False
# 2         False            False          False        False     False
# 3         False            False          False        False     False
# 4         False            False          False        False     False
# ...         ...              ...            ...          ...       ...
# 1486      False            False          False        False     False
# 1487      False            False          False        False     False
# 1488      False            False          False        False     False
# 1489      False            False          False        False     False
# 1490      False            False          False        False     False
#
#       No_of_Passengers  Travel_Time_hrs  Tips_INR  Tourist_Place_Nearby  \
# ...

# %%
df.isnull().sum()
# Out:
# Date_Time                0
# Pickup_Location          0
# Drop_Location            0
# Distance_km             47
# Fare_INR                64
# No_of_Passengers        34
# Travel_Time_hrs         18
# Tips_INR                20
# Tourist_Place_Nearby     0
# Weather_Condition       19
# dtype: int64

# %%
df.fillna(1)
# Out:
#              Date_Time Pickup_Location Drop_Location  Distance_km  Fare_INR  \
# 0     25-10-2011 22:58        Namakkal   Krishnagiri         65.8   1076.40
# 1     03-01-2014 10:11  Ramanathapuram  Nagapattinam          1.0   1298.39
# 2     26-07-2011 10:06     Tirunelveli     Thanjavur        121.7   1869.84
# 3     25-08-2011 19:16           Karur      Namakkal        176.7   2828.04
# 4     07-08-2013 18:29        Namakkal         Theni        281.2   4100.53
# ...                ...             ...           ...          ...       ...
# 1486  11-04-2010 22:48    Nagapattinam     Thanjavur        205.3   3096.91
# 1487  30-09-2011 22:30        Namakkal       Chennai        136.6   2227.24
# 1488  18-10-2015 07:28      Dharmapuri         Karur        107.9   1515.77
# 1489  07-12-2015 18:39     Pudukkottai       Chennai         41.7    734.25
# 1490  09-08-2018 22:29       Sivaganga         Erode        221.8   3959.42
#
#       No_of_Passengers  Travel_Time_hrs  Tips_INR  \
# ...

# %%
df.dropna()
# Out:
#              Date_Time Pickup_Location Drop_Location  Distance_km  Fare_INR  \
# 0     25-10-2011 22:58        Namakkal   Krishnagiri         65.8   1076.40
# 2     26-07-2011 10:06     Tirunelveli     Thanjavur        121.7   1869.84
# 3     25-08-2011 19:16           Karur      Namakkal        176.7   2828.04
# 5     10-12-2017 18:11     Pudukkottai    Dharmapuri        257.3   3265.23
# 6     18-05-2013 03:02         Chennai      Tiruppur        219.7   3317.63
# ...                ...             ...           ...          ...       ...
# 1486  11-04-2010 22:48    Nagapattinam     Thanjavur        205.3   3096.91
# 1487  30-09-2011 22:30        Namakkal       Chennai        136.6   2227.24
# 1488  18-10-2015 07:28      Dharmapuri         Karur        107.9   1515.77
# 1489  07-12-2015 18:39     Pudukkottai       Chennai         41.7    734.25
# 1490  09-08-2018 22:29       Sivaganga         Erode        221.8   3959.42
#
#       No_of_Passengers  Travel_Time_hrs  Tips_INR  \
# ...

# %%
df.isnull().sum()
# Out:
# Date_Time                0
# Pickup_Location          0
# Drop_Location            0
# Distance_km             47
# Fare_INR                64
# No_of_Passengers        34
# Travel_Time_hrs         18
# Tips_INR                20
# Tourist_Place_Nearby     0
# Weather_Condition       19
# dtype: int64

# %%
df.sort_values(by='Pickup_Location')
# Out:
#              Date_Time Pickup_Location Drop_Location  Distance_km  Fare_INR  \
# 432   21-08-2017 18:12         Chennai         Karur          NaN   1445.79
# 873   15-03-2016 18:37         Chennai       Madurai        156.1   2009.94
# 1458  21-08-2015 02:37         Chennai   Krishnagiri        155.3   2788.12
# 1187  02-06-2011 15:23         Chennai    Dharmapuri        219.6   3133.49
# 810   19-02-2011 05:29         Chennai         Theni        209.3   3209.06
# ...                ...             ...           ...          ...       ...
# 669   13-07-2013 09:34    Virudhunagar         Karur        103.6       NaN
# 1433  24-04-2010 07:26    Virudhunagar  Nagapattinam         11.2    154.36
# 272   09-02-2017 10:00    Virudhunagar      Namakkal         82.7   1079.48
# 367   10-05-2015 21:52    Virudhunagar  Nagapattinam         30.6    425.23
# 745   01-06-2013 22:55    Virudhunagar    Villupuram        171.3   2446.98
#
#       No_of_Passengers  Travel_Time_hrs  Tips_INR  \
# ...
